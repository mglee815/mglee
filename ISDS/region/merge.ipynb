# %%
import pandas as pd

# %%
body = pd.read_excel("/home/mglee/VSCODE/git/ISDS/region/body.xlsx")
id = pd.read_excel("/home/mglee/VSCODE/git/ISDS/region/id.xlsx")

# %%
body
# Out:
#      Unnamed: 0  dist type   보건_영역평균   복지_영역평균   교육_영역평균   문화_영역평균  순위:보건  \
# 0           NaN  전라남도    도  6.263236  6.560409  6.027735  5.758826      1
# 1           NaN  경상남도    도  6.002598  5.816905  6.372718  5.515335      4
# 2           NaN  충청남도    도  5.747029  5.805874  6.258403  5.624632      7
# 3           NaN   경기도    도  6.038500  5.940721  6.256226  5.920582      2
# 4           NaN  전라북도    도  6.015614  6.474904  5.844228  6.083551      3
# ..          ...   ...  ...       ...       ...       ...       ...    ...
# 239         NaN    대구  특광시  6.272466  5.651346  6.016530  6.151630      4
# 240         NaN    인천  특광시  5.779436  5.567167  6.384535  5.856523      6
# 241         NaN    광주  특광시  6.440033  6.430276  6.790109  6.341438      2
# 242         NaN    서울  특광시  6.305575  5.458504  6.294514  6.324610      3
# 243         NaN    대전  특광시  6.594207  6.058239  6.487092  6.407663      1
#
#      순위:복지  순위:교육  ...  교육2 표준화값  교육3 표준화값  교육4 표준화값  교육5 표준화값  문화1 표준화값  \
# ...

# %%
temp = pd.merge(body, id[['광역', '자치']], how = 'left', left_on = 'dist', right_on = '자치')

# %%
temp['Unnamed: 0'] = temp['광역']

# %%
temp.to_excel("/home/mglee/VSCODE/git/ISDS/region/merge.xlsx")
